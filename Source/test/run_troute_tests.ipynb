# %% [markdown]
# ### Run T-Route RnR tests
#
# Inside of the T-route RnR library there are some pytests which check for data formatting. We'll use this notebook to run said tests and interpret outputs

# %%
# !docker exec docker-rnr-1 bash -c "source ../../.venv/bin/activate && pytest test"
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.11.12, pytest-8.3.2, pluggy-1.6.0
# rootdir: /t-route/src/troute-rnr
# configfile: pyproject.toml
# plugins: anyio-4.9.0
# collected 1 item
#
# test/test_format.py .                                                    [100%]
#
# =============================== warnings summary ===============================
# ../../.venv/lib/python3.11/site-packages/geopandas/_compat.py:7
#   /t-route/.venv/lib/python3.11/site-packages/geopandas/_compat.py:7: DeprecationWarning: The 'shapely.geos' module is deprecated, and will be removed in a future version. All attributes of 'shapely.geos' are available directly from the top-level 'shapely' namespace (since shapely 2.0.0).
#     import shapely.geos
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ========================= 1 passed, 1 warning in 1.07s =========================
